# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('legoset.csv')

# %%
df.head()
# Out:
#                           name  pieces                price
# 0                Corner Garage  2569.0  $199.99, 179.99€ |
# 1                 Ford Mustang  1471.0  $149.99, 129.99€ |
# 2  NASA Apollo 11 Lunar Lander  1087.0    $99.99, 89.99€ |
# 3            Gingerbread House    24.0                 1477
# 4      Harley-Davidson Fat Boy  1023.0    $99.99, 89.99€ |

# %%
df.isnull().count()
# Out:
# name      743
# pieces    743
# price     743
# dtype: int64

# %%
df = df.dropna()

# %%
df.reset_index(drop=True)
# Out:
#                                                 name  pieces  \
# 0                                      Corner Garage  2569.0
# 1                                       Ford Mustang  1471.0
# 2                        NASA Apollo 11 Lunar Lander  1087.0
# 3                                  Gingerbread House    24.0
# 4                            Harley-Davidson Fat Boy  1023.0
# 5                                         Woody & RC    69.0
# 6                           Duke Caboom's Stunt Show   120.0
# 7            Buzz and Bo Peep's Playground Adventure   139.0
# 8                                        RV Vacation   178.0
# 9                     Buzz & Woody's Carnival Mania!   230.0
# 10                           Carnival Thrill Coaster    98.0
# 11                                My First Tow Truck    11.0
# 12                        My First Balancing Animals    15.0
# 13                            My First Car Creations    34.0
# 14                                      Creative Fun   120.0
# 15                           Mickey's Vacation House    57.0
# 16                            Spider-Man vs. Electro    29.0
# 17                                   Toy Story Train    21.0
# 18   Emmet and Lucy's Visitors from the DUPLO Planet    53.0
# 19                             My First Minnie Build    10.0
# 20                             My First Mickey Build     9.0
# 21                                 Frozen Ice Castle    59.0
# 22                                       Police Bike     8.0
# 23                                        Fire Truck    21.0
# 24                                    Police Station    38.0
# 25                                      Fire Station    76.0
# 26                                      Baby Animals     9.0
# 27                                   Tropical Island    73.0
# 28                                     World Animals   121.0
# 29                                             Plane    12.0
# ..                                               ...     ...
# 347                       Mr. Freeze Batcycle Battle   200.0
# 348                  Batmobile: Pursuit of The Joker   342.0
# 349                    Batwing and The Riddler Heist   489.0
# 350                        Batcave Clayface Invasion  1038.0
# 351                Captain America: Outriders Attack   167.0
# 352                               War Machine Buster   362.0
# 353                          Iron Man Hall of Armour   524.0
# 354                        Avengers Ultimate Quinjet   838.0
# 355             Captain Marvel and The Skrull Attack   307.0
# 356                                Molten Man Battle   294.0
# 357                                 Hydro-Man Attack   471.0
# 358                   Stark Jet and the Drone Attack   504.0
# 359                         Avengers Compound Battle   699.0
# 360                             Spider-Man Car Chase    52.0
# 361                Spider-Man: Doc Ock Diamond Heist   150.0
# 362                   Batman vs. The Riddler Robbery    59.0
# 363                      Batman and The Joker Escape   171.0
# 364                                 Dragon Boat Race   643.0
# 365                                        Boost Hub     1.0
# 366                                  Distance Sensor     1.0
# 367                                            Motor     1.0
# 368                                              Hub     1.0
# 369                                   Remote Control     1.0
# 370                                      Train motor     7.0
# 371                          TLM2 Accessory Set 2019    48.0
# 372                                  Oni Battle Pack     3.0
# 373                                        Emmet Pod     1.0
# 374                         Sweet Mayhem's Disco Pod     1.0
# 375                       Lloyd's Kendo Training Pod     1.0
# 376                               LEGO Greeting Card    40.0
#
#                    price
# 0    $199.99, 179.99€ |
# 1    $149.99, 129.99€ |
# 2      $99.99, 89.99€ |
# 3                   1477
# 4      $99.99, 89.99€ |
# 5        $9.99, 9.99€ |
# 6      $19.99, 19.99€ |
# 7      $24.99, 24.99€ |
# 8      $34.99, 34.99€ |
# 9      $49.99, 49.99€ |
# 10     $19.99, 19.99€ |
# 11       $9.99, 9.99€ |
# 12     $14.99, 14.99€ |
# 13     $19.99, 19.99€ |
# 14     $39.99, 34.99€ |
# 15     $49.99, 49.99€ |
# 16     $19.99, 19.99€ |
# 17     $19.99, 19.99€ |
# 18     $29.99, 29.99€ |
# 19       $9.99, 9.99€ |
# 20       $9.99, 9.99€ |
# 21     $49.99, 49.99€ |
# 22       $9.99, 9.99€ |
# 23     $19.99, 19.99€ |
# 24     $29.99, 29.99€ |
# 25     $49.99, 49.99€ |
# 26       $9.99, 9.99€ |
# 27     $59.99, 59.99€ |
# 28     $99.99, 99.99€ |
# 29       $9.99, 9.99€ |
# ..                   ...
# 347    $19.99, 24.99€ |
# 348    $29.99, 29.99€ |
# 349    $49.99, 49.99€ |
# 350    $99.99, 99.99€ |
# 351    $19.99, 24.99€ |
# 352    $34.99, 34.99€ |
# 353      $59.99, 59.99€
# 354    $79.99, 79.99€ |
# 355    $29.99, 29.99€ |
# 356    $29.99, 29.99€ |
# 357    $39.99, 39.99€ |
# 358    $69.99, 59.99€ |
# 359    $99.99, 99.99€ |
# 360      $9.99, 9.99€ |
# 361    $29.99, 29.99€ |
# 362      $9.99, 9.99€ |
# 363    $39.99, 39.99€ |
# 364    $49.99, 49.99€ |
# 365    $79.99, 79.99€ |
# 366    $13.99, 13.99€ |
# 367    $16.99, 16.99€ |
# 368    $49.99, 49.99€ |
# 369    $22.99, 22.99€ |
# 370    $13.99, 13.99€ |
# 371    $12.99, 12.99€ |
# 372                   36
# 373                   27
# 374                   28
# 375                   25
# 376        $4.99, 4.99€
#
# [377 rows x 3 columns]

# %%
sns.distplot(df['pieces'],kde=False)
plt.show()

# %%
sns.barplot(x=df['price'],y=df['name'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-735db8c5c3b2> in <module>()
# ----> 1 sns.barplot(x=df['price'],y=df['name'])
#       2 plt.show()
#
# /home/milpontia/.local/lib/python2.7/site-packages/seaborn/categorical.pyc in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# /home/milpontia/.local/lib/python2.7/site-packages/seaborn/categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# /home/milpontia/.local/lib/python2.7/site-packages/seaborn/categorical.pyc in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     156
#     157             # Figure out the plotting orientation
# --> 158             orient = self.infer_orient(x, y, orient)
#     159
#     160             # Option 2a:
#
# /home/milpontia/.local/lib/python2.7/site-packages/seaborn/categorical.pyc in infer_orient(self, x, y, orient)
#     359         elif is_not_numeric(y):
#     360             if is_not_numeric(x):
# --> 361                 raise ValueError(no_numeric)
#     362             else:
#     363                 return "h"
#
# ValueError: Neither the `x` nor `y` variable appears to be numeric.
